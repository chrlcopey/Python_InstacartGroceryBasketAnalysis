# %% [markdown]
# # 4.4: Data Wrangling & Subsetting

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# paths
path = '/Users/LuisD/Desktop/01-2025 Instacart Basket Analysis'
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
# Dropping eval_set column from orders.csv
df_ords .drop(columns = ['eval_set'] )

# %%
# Dropping eval_set column from orders.csv
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# Transporting df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Appying changes
df_dep_t = df_dep.T

# %%
# reset index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t for the heater
new_header = df_dep_t.iloc[0]

# %%
# Take the data under the header row for a new df
df_dep_t_new = df_dep_t[1:]

# %%
# Set the header row as the df header
df_dep_t_new.columns = new_header

# %%
# turn your df_dep_t_new dataframe into a dictionary
data_dict = df_dep_t_new.to_dict('index')

# %% [markdown]
# # 4.4: Task Procedures

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
# changed the order_id column to string
df_ords['order_number'] = df_ords['order_number'].astype('str')
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords.describe()
# Out:
#           order_dow  order_hour_of_day  days_since_prior_order
# count  3.421083e+06       3.421083e+06            3.214874e+06
# mean   2.776219e+00       1.345202e+01            1.111484e+01
# std    2.046829e+00       4.226088e+00            9.206737e+00
# min    0.000000e+00       0.000000e+00            0.000000e+00
# 25%    1.000000e+00       1.000000e+01            4.000000e+00
# 50%    3.000000e+00       1.300000e+01            7.000000e+00
# 75%    5.000000e+00       1.600000e+01            1.500000e+01
# max    6.000000e+00       2.300000e+01            3.000000e+01

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
 # # Busiest time of day for orders 
df_ords['order_hour_of_day'].value_counts(dropna=False).sort_index()
# Out:
# order_hour_of_day
# 0      22758
# 1      12398
# 2       7539
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# Name: count, dtype: int64

# %%
# the busiest hour is for placing orders is 10:00 am

# %%
# meaning of 4 in data dictionary
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# show departments dictionary 
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# create a subset that only contains data from the breakfast department
df_breakfast =  df_prods[df_prods['department_id']==14]

# %%
# create a subset that only contains data from the alcohol, deli, beverages, and meat/seafoood department.
# Define the departments of interest
df_prods_dinnerparty = df_prods[df_prods['department_id'].isin([5,7,12,20])]

# %%
# show count of rows and columns 
df_prods_dinnerparty.shape
# Out:
# (7650, 5)

# %%
# the dataframe just created has 7650 rows

# %%
df_user1 = df_ords[df_ords['user_id'] == 1]

# %%
df_user1.describe()
# Out:
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count                 0.0                0.0                     0.0
# mean                  NaN                NaN                     NaN
# std                   NaN                NaN                     NaN
# min                   NaN                NaN                     NaN
# 25%                   NaN                NaN                     NaN
# 50%                   NaN                NaN                     NaN
# 75%                   NaN                NaN                     NaN
# max                   NaN                NaN                     NaN

# %%
df_ords
# Out:
#         order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0        2539329       1            1                   2                  8
# 1        2398795       1            2                   3                  7
# 2         473747       1            3                   3                 12
# 3        2254736       1            4                   4                  7
# 4         431534       1            5                   4                 15
# ...          ...     ...          ...                 ...                ...
# 3421078  2266710  206209           10                   5                 18
# 3421079  1854736  206209           11                   4                 10
# 3421080   626363  206209           12                   1                 12
# 3421081  2977660  206209           13                   1                 12
# 3421082   272231  206209           14                   6                 14
#
#          days_since_prior_order
# ...

# %%
df_user_1 = df_ords[df_ords['user_id'] == 1]

# %%
df_user_1.head()
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_user_1.head(30)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_ords.head(30)
# Out:
#    order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1            1                   2                  8
# 1   2398795       1            2                   3                  7
# 2    473747       1            3                   3                 12
# 3   2254736       1            4                   4                  7
# 4    431534       1            5                   4                 15
# 5   3367565       1            6                   2                  7
# 6    550135       1            7                   1                  9
# 7   3108588       1            8                   1                 14
# 8   2295261       1            9                   1                 16
# 9   2550362       1           10                   4                  8
# 10  1187899       1           11                   4                  8
# 11  2168274       2            1                   2                 11
# ...

# %%
df_ords.head(11)
# Out:
#    order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1            1                   2                  8
# 1   2398795       1            2                   3                  7
# 2    473747       1            3                   3                 12
# 3   2254736       1            4                   4                  7
# 4    431534       1            5                   4                 15
# 5   3367565       1            6                   2                  7
# 6    550135       1            7                   1                  9
# 7   3108588       1            8                   1                 14
# 8   2295261       1            9                   1                 16
# 9   2550362       1           10                   4                  8
# 10  1187899       1           11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
# this customer is buying between the day 1 and 4 from 7 hour to 16 hour.

# %%
# export command
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
#export departments data frame
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
